# %%
import pandas as pd

# %%
df = pd.read_excel('mexico_remittances_2003_2017.xlsx')
df
# Out:
#                   state  amount_ 2003  amount_ 2004  amount_ 2005  \
# 0             Michoacán          1787          2281          2442
# 1               Jalisco          1335          1462          1696
# 2            Guanajuato          1407          1728          1905
# 3      Estado de México          1106          1446          1765
# 4                Puebla           854          1009          1182
# 5                Oaxaca           787           949          1080
# 6              Guerrero           877          1018          1175
# 7      Ciudad de México           815           922          1313
# 8              Veracruz           999          1168          1373
# 9       San Luis Potosí           404           469           562
# 10            Zacatecas           402           485           540
# 11           Nuevo León           189           296           284
# 12              Hidalgo           608           726           815
# ...

# %%
df['total'] = df.sum(axis=1)

# %%
df.sort_values(by='total', ascending=False)
# Out:
#                   state  amount_ 2003  amount_ 2004  amount_ 2005  \
# 32                Total         15139         18332         21688
# 0             Michoacán          1787          2281          2442
# 2            Guanajuato          1407          1728          1905
# 1               Jalisco          1335          1462          1696
# 3      Estado de México          1106          1446          1765
# 4                Puebla           854          1009          1182
# 5                Oaxaca           787           949          1080
# 8              Veracruz           999          1168          1373
# 6              Guerrero           877          1018          1175
# 7      Ciudad de México           815           922          1313
# 12              Hidalgo           608           726           815
# 9       San Luis Potosí           404           469           562
# 10            Zacatecas           402           485           540
# ...

# %%
df.to_csv('total_mex_remittances.csv')
