# %%
import pandas as pd

# %%
df = pd.read_csv('mexico_remittances_2003_2017.csv')
df
# Out:
#                   state    2003    2004    2005    2006    2007    2008  \
# 0             Michoacán   1,787   2,281   2,442   2,504   2,436   2,449
# 1               Jalisco   1,335   1,462   1,696   1,975   1,997   1,915
# 2            Guanajuato   1,407   1,728   1,905   2,311   2,389   2,318
# 3      Estado de México   1,106   1,446   1,765   2,079   2,167   2,067
# 4                Puebla     854   1,009   1,182   1,483   1,618   1,616
# 5                Oaxaca     787     949   1,080   1,360   1,517   1,522
# 6              Guerrero     877   1,018   1,175   1,456   1,490   1,435
# 7      Ciudad de México     815     922   1,313   1,490   1,059   1,084
# 8              Veracruz     999   1,168   1,373   1,681   1,776   1,618
# 9       San Luis Potosí     404     469     562     714     778     761
# 10            Zacatecas     402     485     540     668     687     682
# 11           Nuevo León     189     296     284     343     327     324
# ...

# %%
df['total'] = df['2003'] + df['2004'] + df['2005'] + df['2006'] + df['2007'] + df['2008'] + df['2009'] + df['2010'] + df['2011'] + df['2012'] + df['2013'] + df['2014'] + df['2015'] + df['2016'] + df['2017']

# %%
df
# Out:
#                   state    2003    2004    2005    2006    2007    2008  \
# 0             Michoacán   1,787   2,281   2,442   2,504   2,436   2,449
# 1               Jalisco   1,335   1,462   1,696   1,975   1,997   1,915
# 2            Guanajuato   1,407   1,728   1,905   2,311   2,389   2,318
# 3      Estado de México   1,106   1,446   1,765   2,079   2,167   2,067
# 4                Puebla     854   1,009   1,182   1,483   1,618   1,616
# 5                Oaxaca     787     949   1,080   1,360   1,517   1,522
# 6              Guerrero     877   1,018   1,175   1,456   1,490   1,435
# 7      Ciudad de México     815     922   1,313   1,490   1,059   1,084
# 8              Veracruz     999   1,168   1,373   1,681   1,776   1,618
# 9       San Luis Potosí     404     469     562     714     778     761
# 10            Zacatecas     402     485     540     668     687     682
# 11           Nuevo León     189     296     284     343     327     324
# ...

# %%
df.to_csv('total_mex_remittances.csv')
